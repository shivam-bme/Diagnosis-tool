# %%
from tensorflow import keras
from transformers import ViTFeatureExtractor, TFViTForImageClassification
import tensorflow as tf
# Out:
# 2024-06-27 10:51:12.910885: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#!pip install transformers

# %%
import os
import cv2

def extract_frames(video_path, label, output_dir):
    cap = cv2.VideoCapture(video_path)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_rate = int(cap.get(cv2.CAP_PROP_FPS))
    
    count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_name = os.path.join(output_dir, f"{label}_frame_{count:04d}.jpg")
        cv2.imwrite(frame_name, frame)
        print(cv2.imwrite(frame_name, frame))
        count += 1
    cap.release()

# Set your paths
base_dir = r'/media/shivam_singh/New Volume/DownloadsMain/focal_liver_small/'
output_dir = r'/home/shivam_singh/Downloads/frames'
labels = ['FNH-20240626T061834Z-001/FNH', 'HCC-20240626T055858Z-003/HCC','HCC-20240626T055858Z-002/HCC','HCC-20240626T055858Z-001/HCC', 'HHE-20240626T060904Z-001/HHE','HHE-20240626T060904Z-002/HHE']

for label in labels:
    folder_path = os.path.join(base_dir, label)
    video_files = [f for f in os.listdir(folder_path) if f.endswith('.avi')]
    
    for video_file in video_files:
        video_path = os.path.join(folder_path, video_file)
        extract_frames(video_path, label, output_dir)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
import os
from moviepy.editor import VideoFileClip
from PIL import Image

def extract_frames(video_path, label, output_dir):
    # Create a specific output directory for the label
    label_output_dir = os.path.join(output_dir, label)
    if not os.path.exists(label_output_dir):
        os.makedirs(label_output_dir)
    
    clip = VideoFileClip(video_path)
    frame_rate = clip.fps
    duration = clip.duration  # Duration in seconds
    total_frames = int(frame_rate * duration)
    
    print(f"Total frames: {total_frames}, Frame rate: {frame_rate}")
    
    count = 0
    for frame in clip.iter_frames(fps=frame_rate):
        frame_name = os.path.join(label_output_dir, f"{label}_frame_{count:04d}.png")
        try:
            frame_image = Image.fromarray(frame)
            frame_image.save(frame_name)
            print(f"Saved frame: {frame_name}")
        except Exception as e:
            print(f"Failed to save frame: {frame_name}, Error: {e}")
        
        count += 1

# Set your paths
base_dir = '/media/shivam_singh/New Volume/DownloadsMain/focal_liver/'
output_dir = '/media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/'
labels = ['FNH-20240626T061834Z-001/FNH', 'HCC-20240626T055858Z-003/HCC', 'HCC-20240626T055858Z-002/HCC', 'HCC-20240626T055858Z-001/HCC', 'HHE-20240626T060904Z-001/HHE', 'HHE-20240626T060904Z-002/HHE']

for label in labels:
    folder_path = os.path.join(base_dir, label)
    if not os.path.exists(folder_path):
        print(f"Folder does not exist: {folder_path}")
        continue
    
    video_files = [f for f in os.listdir(folder_path) if f.endswith('.avi')]
    
    if not video_files:
        print(f"No video files found in folder: {folder_path}")
        continue
    
    for video_file in video_files:
        video_path = os.path.join(folder_path, video_file)
        print(f"Processing video: {video_path}")
        extract_frames(video_path, label.replace('/', '_'), output_dir)
# Out:
# Processing video: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/FNH-20240626T061834Z-001/FNH/44.avi
# Total frames: 1116, Frame rate: 25.0
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0000.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0001.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0002.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0003.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0004.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0005.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0006.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0007.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0008.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0009.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0010.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0011.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0012.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0013.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0014.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0015.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0016.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0017.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0018.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0019.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0020.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0021.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0022.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0023.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0024.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0025.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0026.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0027.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0028.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0029.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0030.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0031.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0032.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0033.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0034.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0035.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0036.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0037.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0038.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0039.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0040.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0041.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0042.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0043.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0044.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0045.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0046.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0047.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0048.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0049.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0050.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0051.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0052.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0053.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0054.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0055.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0056.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0057.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0058.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0059.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0060.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0061.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0062.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0063.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0064.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0065.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0066.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0067.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0068.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0069.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0070.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0071.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0072.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0073.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0074.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0075.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0076.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0077.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0078.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0079.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0080.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0081.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0082.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0083.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0084.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0085.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0086.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0087.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0088.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0089.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0090.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0091.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0092.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0093.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0094.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0095.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0096.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0097.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0098.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0099.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0100.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0101.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0102.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0103.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0104.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0105.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0106.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0107.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0108.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0109.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0110.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0111.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0112.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0113.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0114.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0115.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0116.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0117.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0118.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0119.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0120.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0121.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0122.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0123.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0124.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0125.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0126.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0127.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0128.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0129.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0130.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0131.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0132.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0133.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0134.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0135.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0136.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0137.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0138.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0139.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0140.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0141.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0142.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0143.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0144.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0145.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0146.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0147.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0148.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0149.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0150.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0151.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0152.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0153.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0154.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0155.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0156.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0157.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0158.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0159.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0160.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0161.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0162.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0163.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0164.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0165.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0166.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0167.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0168.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0169.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0170.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0171.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0172.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0173.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0174.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0175.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0176.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0177.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0178.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0179.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0180.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0181.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0182.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0183.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0184.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0185.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0186.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0187.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0188.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0189.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0190.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0191.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0192.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0193.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0194.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0195.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0196.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0197.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0198.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0199.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0200.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0201.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0202.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0203.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0204.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0205.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0206.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0207.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0208.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0209.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0210.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0211.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0212.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0213.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0214.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0215.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0216.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0217.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0218.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0219.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0220.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0221.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0222.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0223.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0224.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0225.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0226.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0227.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0228.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0229.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0230.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0231.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0232.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0233.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0234.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0235.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0236.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0237.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0238.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0239.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0240.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0241.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0242.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0243.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0244.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0245.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0246.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0247.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0248.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0249.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0250.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0251.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0252.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0253.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0254.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0255.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0256.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0257.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0258.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0259.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0260.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0261.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0262.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0263.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0264.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0265.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0266.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0267.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0268.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0269.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0270.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0271.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0272.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0273.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0274.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0275.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0276.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0277.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0278.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0279.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0280.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0281.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0282.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0283.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0284.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0285.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0286.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0287.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0288.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0289.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0290.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0291.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0292.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0293.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0294.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0295.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0296.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0297.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0298.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0299.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0300.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0301.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0302.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0303.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0304.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0305.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0306.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0307.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0308.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0309.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0310.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0311.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0312.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0313.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0314.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0315.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0316.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0317.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_0318.png
# ...
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1306.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1307.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1308.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1309.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1310.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1311.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1312.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1313.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1314.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1315.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1316.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1317.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1318.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1319.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1320.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1321.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1322.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1323.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1324.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1325.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1326.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1327.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1328.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1329.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1330.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1331.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1332.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1333.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1334.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1335.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1336.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1337.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1338.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1339.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1340.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1341.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1342.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1343.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1344.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1345.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1346.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1347.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1348.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1349.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1350.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1351.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1352.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1353.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1354.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1355.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1356.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1357.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1358.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1359.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1360.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1361.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1362.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1363.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1364.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1365.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1366.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1367.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1368.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1369.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1370.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1371.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1372.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1373.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1374.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1375.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1376.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1377.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1378.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1379.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1380.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1381.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1382.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1383.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1384.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1385.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1386.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1387.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1388.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1389.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1390.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1391.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1392.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1393.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1394.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1395.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1396.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1397.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1398.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1399.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1400.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1401.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1402.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1403.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1404.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1405.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1406.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1407.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1408.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1409.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1410.png
# Saved frame: /media/shivam_singh/New Volume/DownloadsMain/focal_liver/frames/FNH-20240626T061834Z-001_FNH/FNH-20240626T061834Z-001_FNH_frame_1411.png

# %%
import tensorflow as tf

IMG_SIZE = 224  # Example size

def preprocess_image(image_path, label):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
    image = image / 255.0  # Normalize to [0, 1]
    return image, label

def load_dataset(image_paths, labels):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
    dataset = dataset.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    return dataset

# Get image paths and labels
image_paths = [os.path.join(output_dir, f) for f in os.listdir(output_dir) if f.endswith('.jpg')]
labels = [1 if 'FNH' in p else 2 if 'HCC' in p else 3 for p in image_paths]

# Create dataset
dataset = load_dataset(image_paths, labels)
dataset = dataset.shuffle(buffer_size=1000).batch(32).prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# 2024-06-27 10:51:48.809270: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      19 labels = [1 if 'FNH' in p else 2 if 'HCC' in p else 3 for p in image_paths]
#      21 # Create dataset
# ---> 22 dataset = load_dataset(image_paths, labels)
#      23 dataset = dataset.shuffle(buffer_size=1000).batch(32).prefetch(buffer_size=tf.data.AUTOTUNE)
#
# Cell In[4], line 14, in load_dataset(image_paths, labels)
#      12 def load_dataset(image_paths, labels):
#      13     dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))
# ---> 14     dataset = dataset.map(preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
#      15     return dataset
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/dataset_ops.py:2240, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2236 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2237 # dataset_ops).
#    2238 # pylint: disable=g-import-not-at-top,protected-access
#    2239 from tensorflow.python.data.ops import map_op
# -> 2240 return map_op._map_v2(
#    2241     self,
#    2242     map_func,
#    2243     num_parallel_calls=num_parallel_calls,
#    2244     deterministic=deterministic,
#    2245     name=name)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/map_op.py:40, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
# ---> 40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#      43       num_parallel_calls=num_parallel_calls,
#      44       deterministic=deterministic,
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/map_op.py:148, in _ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     146 self._input_dataset = input_dataset
#     147 self._use_inter_op_parallelism = use_inter_op_parallelism
# --> 148 self._map_func = structured_function.StructuredFunctionWrapper(
#     149     map_func,
#     150     self._transformation_name(),
#     151     dataset=input_dataset,
#     152     use_legacy_function=use_legacy_function)
#     153 if deterministic is None:
#     154   self._deterministic = "default"
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py:261, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     254       warnings.warn(
#     255           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     256           "option is set, this option does not apply to tf.data functions. "
#     257           "To force eager execution of tf.data functions, please use "
#     258           "`tf.data.experimental.enable_debug_mode()`.")
#     259     fn_factory = trace_tf_function(defun_kwargs)
# --> 261 self._function = fn_factory()
#     262 # There is no graph to add in eager mode.
#     263 add_to_graph &= not context.executing_eagerly()
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:232, in TracingCompiler.get_concrete_function(self, *args, **kwargs)
#     223 def get_concrete_function(self, *args, **kwargs):
#     224   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#     225
#     226   Args:
#    (...)
#     230       `tf.Tensor` or `tf.TensorSpec`.
#     231   """
# --> 232   concrete_function = self._get_concrete_function_garbage_collected(
#     233       *args, **kwargs)
#     234   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#     235   return concrete_function
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:202, in TracingCompiler._get_concrete_function_garbage_collected(self, *args, **kwargs)
#     199   self._function_spec.make_canonicalized_monomorphic_type(args, kwargs)
#     201 with self._lock:
# --> 202   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     203   seen_names = set()
#     204   concrete_function._arg_keywords = []  # pylint: disable=protected-access
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:166, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     163   args = self.input_signature
#     164   kwargs = {}
# --> 166 return self._maybe_define_function(args, kwargs)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:396, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     393   args = placeholder_bound_args.args
#     394 kwargs = placeholder_bound_args.kwargs
# --> 396 concrete_function = self._create_concrete_function(
#     397     args, kwargs, func_graph)
#     399 # TODO(b/263520817): Remove access to private attribute.
#     400 graph_capture_container = concrete_function.graph._function_captures  # pylint: disable=protected-access
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:300, in TracingCompiler._create_concrete_function(self, args, kwargs, func_graph)
#     296 else:
#     297   arg_names = base_arg_names
#     299 concrete_function = monomorphic_function.ConcreteFunction(
# --> 300     func_graph_module.func_graph_from_py_func(
#     301         self._name,
#     302         self._python_function,
#     303         args,
#     304         kwargs,
#     305         None,
#     306         func_graph=func_graph,
#     307         autograph=self._autograph,
#     308         autograph_options=self._autograph_options,
#     309         arg_names=arg_names,
#     310         capture_by_value=self._capture_by_value,
#     311         create_placeholders=False),
#     312     self._function_attributes,
#     313     spec=self.function_spec,
#     314     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     315     # scope. This is not the default behavior since it gets used in some
#     316     # places (like Keras) where the FuncGraph lives longer than the
#     317     # ConcreteFunction.
#     318     shared_func_graph=False)
#     319 return concrete_function
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/func_graph.py:1214, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders, acd_record_initial_resource_uses)
#    1211 else:
#    1212   _, original_func = tf_decorator.unwrap(python_func)
# -> 1214 func_outputs = python_func(*func_args, **func_kwargs)
#    1216 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1217 # TensorArrays and `None`s.
#    1218 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py:238, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     232 @eager_function.defun_with_attributes(
#     233     input_signature=structure.get_flat_tensor_specs(
#     234         self._input_structure),
#     235     autograph=False,
#     236     attributes=defun_kwargs)
#     237 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 238   ret = wrapper_helper(*args)
#     239   ret = structure.to_tensor_list(self._output_structure, ret)
#     240   return [ops.convert_to_tensor(t) for t in ret]
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/data/ops/structured_function.py:169, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     167 if not _should_unpack(nested_args):
#     168   nested_args = (nested_args,)
# --> 169 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     170 ret = variable_utils.convert_variables_to_tensors(ret)
#     171 if _should_pack(ret):
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:692, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
# --> 692     raise e.ag_error_metadata.to_exception(e)
#     693   else:
#     694     raise
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:689, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     687 try:
#     688   with conversion_ctx:
# --> 689     return converted_call(f, args, kwargs, options=options)
#     690 except Exception as e:  # pylint:disable=broad-except
#     691   if hasattr(e, 'ag_error_metadata'):
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_file8n5pd7e3.py:10, in outer_factory.<locals>.inner_factory.<locals>.tf__preprocess_image(image_path, label)
#       8 do_return = False
#       9 retval_ = ag__.UndefinedReturnValue()
# ---> 10 image = ag__.converted_call(ag__.ld(tf).io.read_file, (ag__.ld(image_path),), None, fscope)
#      11 image = ag__.converted_call(ag__.ld(tf).image.decode_jpeg, (ag__.ld(image),), dict(channels=3), fscope)
#      12 image = ag__.converted_call(ag__.ld(tf).image.resize, (ag__.ld(image), [ag__.ld(IMG_SIZE), ag__.ld(IMG_SIZE)]), None, fscope)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     457 if kwargs is not None:
#     458   return f(*args, **kwargs)
# --> 459 return f(*args)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/io_ops.py:133, in read_file(filename, name)
#      96 @tf_export("io.read_file", v1=["io.read_file", "read_file"])
#      97 def read_file(filename, name=None):
#      98   """Reads the contents of file.
#      99
#     100   This operation returns a tensor with the entire contents of the input
#    (...)
#     131     A tensor of dtype "string", with the file contents.
#     132   """
# --> 133   return gen_io_ops.read_file(filename, name)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/ops/gen_io_ops.py:586, in read_file(filename, name)
#     584     pass  # Add nodes to the TensorFlow graph.
#     585 # Add nodes to the TensorFlow graph.
# --> 586 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#     587       "ReadFile", filename=filename, name=name)
#     588 _result = _outputs[:]
#     589 if _execute.must_record_gradient():
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py:777, in _apply_op_helper(op_type_name, name, **keywords)
#     775 with g.as_default(), ops.name_scope(name) as scope:
#     776   if fallback:
# --> 777     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     778                            keywords, default_type_attr_map, attrs, inputs,
#     779                            input_types)
#     780     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     781                            default_type_attr_map, attrs)
#     782     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py:577, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     574 prefix = ("Input '%s' of '%s' Op has type %s that does not match" %
#     575           (input_name, op_type_name, observed))
#     576 if input_arg.type != types_pb2.DT_INVALID:
# --> 577   raise TypeError(f"{prefix} expected type of "
#     578                   f"{dtypes.as_dtype(input_arg.type).name}.")
#     579 else:
#     580   # Update the maps with the default, if needed.
#     581   k = input_arg.type_attr
#
# TypeError: in user code:
#
#     File "/tmp/ipykernel_7347/4292465204.py", line 6, in preprocess_image  *
#         image = tf.io.read_file(image_path)
#
#     TypeError: Input 'filename' of 'ReadFile' Op has type float32 that does not match expected type of string.

# %%
# Load pre-trained ViT model
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')
model = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224', num_labels=3,ignore_mismatched_sizes=True)

# Compile model
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
              loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=[keras.metrics.SparseCategoricalAccuracy()])
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# /home/shivam_singh/anaconda3/envs/tf/lib/python3.9/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# 2024-06-26 12:23:52.051311: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/transformers/modeling_tf_pytorch_utils.py:407, in load_pytorch_state_dict_in_tf2_model(tf_model, pt_state_dict, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename, ignore_mismatched_sizes, skip_logger_warnings)
#     406 try:
# --> 407     array = apply_transpose(transpose, array, symbolic_weight.shape)
#     408 except tf.errors.InvalidArgumentError as e:
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/transformers/modeling_tf_pytorch_utils.py:157, in apply_transpose(transpose, weight, match_shape, pt_to_tf)
#     156 try:
# --> 157     weight = reshape(weight, match_shape)
#     158 except AssertionError as e:
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/transformers/utils/generic.py:642, in reshape(array, newshape)
#     640     import tensorflow as tf
# --> 642     return tf.reshape(array, newshape)
#     643 elif is_jax_tensor(array):
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#
# InvalidArgumentError: {{function_node __wrapped__Reshape_device_/job:localhost/replica:0/task:0/device:CPU:0}} Input to reshape is a tensor with 768000 values, but the requested shape has 2304 [Op:Reshape]
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Load pre-trained ViT model
#       2 feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')
# ----> 3 model = TFViTForImageClassification.from_pretrained('google/vit-base-patch16-224', num_labels=3)
#       5 # Compile model
#       6 model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-5),
#       7               loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#       8               metrics=[keras.metrics.SparseCategoricalAccuracy()])
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/transformers/modeling_tf_utils.py:2984, in TFPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2978     from .modeling_tf_pytorch_utils import load_pytorch_state_dict_in_tf2_model
#    2980     with safe_open(resolved_archive_file, framework="tf") as safetensors_archive:
#    2981         # Load from a PyTorch safetensors checkpoint
#    2982         # We load in TF format here because PT weights often need to be transposed, and this is much
#    2983         # faster on GPU. Loading as numpy and transposing on CPU adds several seconds to load times.
# -> 2984         return load_pytorch_state_dict_in_tf2_model(
#    2985             model,
#    2986             safetensors_archive,
#    2987             tf_inputs=False,  # No need to build the model again
#    2988             allow_missing_keys=True,
#    2989             output_loading_info=output_loading_info,
#    2990             _prefix=load_weight_prefix,
#    2991             ignore_mismatched_sizes=ignore_mismatched_sizes,
#    2992             tf_to_pt_weight_rename=tf_to_pt_weight_rename,
#    2993         )
#    2994 elif safetensors_from_pt:
#    2995     from .modeling_tf_pytorch_utils import load_sharded_pytorch_safetensors_in_tf2_model
#
# File ~/anaconda3/envs/tf/lib/python3.9/site-packages/transformers/modeling_tf_pytorch_utils.py:414, in load_pytorch_state_dict_in_tf2_model(tf_model, pt_state_dict, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename, ignore_mismatched_sizes, skip_logger_warnings)
#     410     error_msg = str(e)
#     411     error_msg += (
#     412         "\n\tYou may consider adding `ignore_mismatched_sizes=True` in the model `from_pretrained` method."
#     413     )
# --> 414     raise tf.errors.InvalidArgumentError(error_msg)
#     415 else:
#     416     mismatched_keys.append((name, array.shape, symbolic_weight.shape))
#
# TypeError: __init__() missing 2 required positional arguments: 'op' and 'message'

# %%
import matplotlib.pyplot as plt
import torch, torchvision

from torch import nn
from torchvision import transformers
device = "cuda" if torch.cuda.is_available() else "cpu"
device

# %%
import os

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

NUM_WORKERS = os.cpu_count()

def create_dataloaders(
    train_dir: str, 
    test_dir: str, 
    transform: transforms.Compose, 
    batch_size: int, 
    num_workers: int=NUM_WORKERS
):

  # Use ImageFolder to create dataset(s)
  train_data = datasets.ImageFolder(train_dir, transform=transform)
  test_data = datasets.ImageFolder(test_dir, transform=transform)

  # Get class names
  class_names = train_data.classes

  # Turn images into data loaders
  train_dataloader = DataLoader(
      train_data,
      batch_size=batch_size,
      shuffle=True,
      num_workers=num_workers,
      pin_memory=True,
  )
  test_dataloader = DataLoader(
      test_data,
      batch_size=batch_size,
      shuffle=False,
      num_workers=num_workers,
      pin_memory=True,
  )

  return train_dataloader, test_dataloader, class_names

# %%
# Set the batch size
BATCH_SIZE = 32 

# Create data loaders
train_dataloader, test_dataloader, class_names = create_dataloaders(
    train_dir=train_dir,
    test_dir=test_dir,
    transform=manual_transforms, 
    batch_size=BATCH_SIZE
)

train_dataloader, test_dataloader, class_names

# %%
# Let's visualize a image in order to know if data is loaded properly or not

# Get a batch of images
image_batch, label_batch = next(iter(train_dataloader))

# Get a single image from the batch
image, label = image_batch[0], label_batch[0]

# View the batch shapes
print(image.shape, label)

# Plot image with matplotlib
plt.imshow(image.permute(1, 2, 0)) # rearrange image dimensions to suit matplotlib [color_channels, height, width] -> [height, width, color_channels]
plt.title(class_names[label])
plt.axis(False);

# %%
# 1. Create a class which subclasses nn.Module
class PatchEmbedding(nn.Module):
    """Turns a 2D input image into a 1D sequence learnable embedding vector.
    
    Args:
        in_channels (int): Number of color channels for the input images. Defaults to 3.
        patch_size (int): Size of patches to convert input image into. Defaults to 16.
        embedding_dim (int): Size of embedding to turn image into. Defaults to 768.
    """ 
    # 2. Initialize the class with appropriate variables
    def __init__(self, 
                 in_channels:int=3,
                 patch_size:int=16,
                 embedding_dim:int=768):
        super().__init__()
        
        # 3. Create a layer to turn an image into patches
        self.patcher = nn.Conv2d(in_channels=in_channels,
                                 out_channels=embedding_dim,
                                 kernel_size=patch_size,
                                 stride=patch_size,
                                 padding=0)

        # 4. Create a layer to flatten the patch feature maps into a single dimension
        self.flatten = nn.Flatten(start_dim=2, # only flatten the feature map dimensions into a single vector
                                  end_dim=3)

    # 5. Define the forward method 
    def forward(self, x):
        # Create assertion to check that inputs are the correct shape
        image_resolution = x.shape[-1]
        assert image_resolution % patch_size == 0, f"Input image size must be divisble by patch size, image shape: {image_resolution}, patch size: {patch_size}"
        
        # Perform the forward pass
        x_patched = self.patcher(x)
        x_flattened = self.flatten(x_patched) 
        
        # 6. Make sure the output shape has the right order 
        return x_flattened.permute(0, 2, 1) # adjust so the embedding is on the final dimension [batch_size, P^2•C, N] -> [batch_size, N, P^2•C]

# %%
# Let's test it on single image
patch_size =16

# Set seeds
def set_seeds(seed: int=42):
    """Sets random sets for torch operations.

    Args:
        seed (int, optional): Random seed to set. Defaults to 42.
    """
    # Set the seed for general torch operations
    torch.manual_seed(seed)
    # Set the seed for CUDA torch operations (ones that happen on the GPU)
    torch.cuda.manual_seed(seed)
    
    
    
set_seeds()

# Create an instance of patch embedding layer
patchify = PatchEmbedding(in_channels=3,
                          patch_size=16,
                          embedding_dim=768)

# Pass a single image through
print(f"Input image shape: {image.unsqueeze(0).shape}")
patch_embedded_image = patchify(image.unsqueeze(0)) # add an extra batch dimension on the 0th index, otherwise will error
print(f"Output patch embedding shape: {patch_embedded_image.shape}")

# %%
# View the patch embedding and patch embedding shape


print(patch_embedded_image) 
print(f"Patch embedding shape: {patch_embedded_image.shape} -> [batch_size, number_of_patches, embedding_dimension]")

# %%
# Now add the the learnable class embedding and position embeddings
# From start to positional encoding: All in 1 cell

set_seeds()

# 1. Set patch size
patch_size = 16

# 2. Print shape of original image tensor and get the image dimensions
print(f"Image tensor shape: {image.shape}")
height, width = image.shape[1], image.shape[2]

# 3. Get image tensor and add batch dimension
x = image.unsqueeze(0)
print(f"Input image with batch dimension shape: {x.shape}")

# 4. Create patch embedding layer
patch_embedding_layer = PatchEmbedding(in_channels=3,
                                       patch_size=patch_size,
                                       embedding_dim=768)

# 5. Pass image through patch embedding layer
patch_embedding = patch_embedding_layer(x)
print(f"Patching embedding shape: {patch_embedding.shape}")



# 6. Create class token embedding
batch_size = patch_embedding.shape[0]
embedding_dimension = patch_embedding.shape[-1]
class_token = nn.Parameter(torch.ones(batch_size, 1, embedding_dimension),
                           requires_grad=True) # make sure it's learnable
print(f"Class token embedding shape: {class_token.shape}")

# 7. Prepend class token embedding to patch embedding
patch_embedding_class_token = torch.cat((class_token, patch_embedding), dim=1)
print(f"Patch embedding with class token shape: {patch_embedding_class_token.shape}")

# 8. Create position embedding
number_of_patches = int((height * width) / patch_size**2)
position_embedding = nn.Parameter(torch.ones(1, number_of_patches+1, embedding_dimension),
                                  requires_grad=True) # make sure it's learnable


# 9. Add position embedding to patch embedding with class token
patch_and_position_embedding = patch_embedding_class_token + position_embedding
print(f"Patch and position embedding shape: {patch_and_position_embedding.shape}")
#patch_and_position_embedding

print(patch_embedding_class_token)  #1 is added in the beginning of each

# %% [markdown]
# Lets create layers used in Transformer's encoder:
# Norm (LN or LayerNorm) - torch.nn.LayerNorm().
#
# Layer Normalization (torch.nn.LayerNorm() or Norm or LayerNorm or LN) normalizes an input over the last dimension.
#
# Layer Normalization helps improve training time and model generalization (ability to adapt to unseen data).
# We can implement the MSA layer in PyTorch with torch.nn.MultiheadAttention() with the parameters:
#
# Multi-Head Self Attention (MSA) - torch.nn.MultiheadAttention()
#
# embed_dim - the embedding dimension D .
#
# num_heads - how many attention heads to use (this is where the term "multihead" comes from)
#
# dropout - whether or not to apply dropout to the attention layer
#
# batch_first - does our batch dimension come first? (yes it does)

# %%
# 1. Create a class that inherits from nn.Module
class MultiheadSelfAttentionBlock(nn.Module):
    """Creates a multi-head self-attention block ("MSA block" for short).
    """
    # 2. Initialize the class with hyperparameters from Table 1
    def __init__(self,
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 attn_dropout:float=0): # doesn't look like the paper uses any dropout in MSABlocks
        super().__init__()
        
        # 3. Create the Norm layer (LN)
        self.layer_norm = nn.LayerNorm(normalized_shape=embedding_dim)
        
        # 4. Create the Multi-Head Attention (MSA) layer
        self.multihead_attn = nn.MultiheadAttention(embed_dim=embedding_dim,
                                                    num_heads=num_heads,
                                                    dropout=attn_dropout,
                                                    batch_first=True) # does our batch dimension come first?
        
    # 5. Create a forward() method to pass the data throguh the layers
    def forward(self, x):
        x = self.layer_norm(x)
        attn_output, _ = self.multihead_attn(query=x, # query embeddings 
                                             key=x, # key embeddings
                                             value=x, # value embeddings
                                             need_weights=False) # do we need the weights or just the layer outputs?
        return attn_output

# %%
# mlp Block
# 1. Create a class that inherits from nn.Module
class MLPBlock(nn.Module):
    """Creates a layer normalized multilayer perceptron block ("MLP block" for short)."""
    # 2. Initialize the class with hyperparameters from Table 1 and Table 3
    def __init__(self,
                 embedding_dim:int=768, # Hidden Size D from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 dropout:float=0.1): # Dropout from Table 3 for ViT-Base
        super().__init__()
        
        # 3. Create the Norm layer (LN)
        self.layer_norm = nn.LayerNorm(normalized_shape=embedding_dim)
        
        # 4. Create the Multilayer perceptron (MLP) layer(s)
        self.mlp = nn.Sequential(
            nn.Linear(in_features=embedding_dim,
                      out_features=mlp_size),
            nn.GELU(), # "The MLP contains two layers with a GELU non-linearity (section 3.1)."
            nn.Dropout(p=dropout),
            nn.Linear(in_features=mlp_size, # needs to take same in_features as out_features of layer above
                      out_features=embedding_dim), # take back to embedding_dim
            nn.Dropout(p=dropout) # "Dropout, when used, is applied after every dense layer.."
        )
    
    # 5. Create a forward() method to pass the data throguh the layers
    def forward(self, x):
        x = self.layer_norm(x)
        x = self.mlp(x)
        return x

# %%
# 1. Create a class that inherits from nn.Module
class TransformerEncoderBlock(nn.Module):
    """Creates a Transformer Encoder block."""
    # 2. Initialize the class with hyperparameters from Table 1 and Table 3
    def __init__(self,
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 mlp_dropout:float=0.1, # Amount of dropout for dense layers from Table 3 for ViT-Base
                 attn_dropout:float=0): # Amount of dropout for attention layers
        super().__init__()

        # 3. Create MSA block (equation 2)
        self.msa_block = MultiheadSelfAttentionBlock(embedding_dim=embedding_dim,
                                                     num_heads=num_heads,
                                                     attn_dropout=attn_dropout)
        
        # 4. Create MLP block (equation 3)
        self.mlp_block =  MLPBlock(embedding_dim=embedding_dim,
                                   mlp_size=mlp_size,
                                   dropout=mlp_dropout)
        
    # 5. Create a forward() method  
    def forward(self, x):
        
        # 6. Create residual connection for MSA block (add the input to the output)
        x =  self.msa_block(x) + x 
        
        # 7. Create residual connection for MLP block (add the input to the output)
        x = self.mlp_block(x) + x 
        
        return x

# %%
transformer_encoder_block = TransformerEncoderBlock()

from torchinfo import summary
# # Print an input and output summary of our Transformer Encoder (uncomment for full output)
summary(model=transformer_encoder_block,
        input_size=(1, 197, 768), # (batch_size, num_patches, embedding_dimension)
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
       row_settings=["var_names"])

# %%
# 1. Create a ViT class that inherits from nn.Module
class ViT(nn.Module):
    """Creates a Vision Transformer architecture with ViT-Base hyperparameters by default."""
    # 2. Initialize the class with hyperparameters from Table 1 and Table 3
    def __init__(self,
                 img_size:int=224, # Training resolution from Table 3 in ViT paper
                 in_channels:int=3, # Number of channels in input image
                 patch_size:int=16, # Patch size
                 num_transformer_layers:int=12, # Layers from Table 1 for ViT-Base
                 embedding_dim:int=768, # Hidden size D from Table 1 for ViT-Base
                 mlp_size:int=3072, # MLP size from Table 1 for ViT-Base
                 num_heads:int=12, # Heads from Table 1 for ViT-Base
                 attn_dropout:float=0, # Dropout for attention projection
                 mlp_dropout:float=0.1, # Dropout for dense/MLP layers 
                 embedding_dropout:float=0.1, # Dropout for patch and position embeddings
                 num_classes:int=1000): # Default for ImageNet but can customize this
        super().__init__() # don't forget the super().__init__()!
        
        # 3. Make the image size is divisble by the patch size 
        assert img_size % patch_size == 0, f"Image size must be divisible by patch size, image size: {img_size}, patch size: {patch_size}."
        
        # 4. Calculate number of patches (height * width/patch^2)
        self.num_patches = (img_size * img_size) // patch_size**2
                 
        # 5. Create learnable class embedding (needs to go at front of sequence of patch embeddings)
        self.class_embedding = nn.Parameter(data=torch.randn(1, 1, embedding_dim),
                                            requires_grad=True)
        
        # 6. Create learnable position embedding
        self.position_embedding = nn.Parameter(data=torch.randn(1, self.num_patches+1, embedding_dim),
                                               requires_grad=True)
                
        # 7. Create embedding dropout value
        self.embedding_dropout = nn.Dropout(p=embedding_dropout)
        
        # 8. Create patch embedding layer
        self.patch_embedding = PatchEmbedding(in_channels=in_channels,
                                              patch_size=patch_size,
                                              embedding_dim=embedding_dim)
        
        # 9. Create Transformer Encoder blocks (we can stack Transformer Encoder blocks using nn.Sequential()) 
        # Note: The "*" means "all"
        self.transformer_encoder = nn.Sequential(*[TransformerEncoderBlock(embedding_dim=embedding_dim,
                                                                            num_heads=num_heads,
                                                                            mlp_size=mlp_size,
                                                                            mlp_dropout=mlp_dropout) for _ in range(num_transformer_layers)])
       
        # 10. Create classifier head
        self.classifier = nn.Sequential(
            nn.LayerNorm(normalized_shape=embedding_dim),
            nn.Linear(in_features=embedding_dim, 
                      out_features=num_classes)
        )
    
    # 11. Create a forward() method
    def forward(self, x):
        
        # 12. Get batch size
        batch_size = x.shape[0]
        
        # 13. Create class token embedding and expand it to match the batch size (equation 1)
        class_token = self.class_embedding.expand(batch_size, -1, -1) # "-1" means to infer the dimension (try this line on its own)

        # 14. Create patch embedding (equation 1)
        x = self.patch_embedding(x)

        # 15. Concat class embedding and patch embedding (equation 1)
        x = torch.cat((class_token, x), dim=1)

        # 16. Add position embedding to patch embedding (equation 1) 
        x = self.position_embedding + x

        # 17. Run embedding dropout (Appendix B.1)
        x = self.embedding_dropout(x)

        # 18. Pass patch, position and class embedding through transformer encoder layers (equations 2 & 3)
        x = self.transformer_encoder(x)

        # 19. Put 0 index logit through classifier (equation 4)
        x = self.classifier(x[:, 0]) # run on each sample in a batch at 0 index

        return x

# %%
#train model 
# Train our MOdel

# Create an instance of ViT with the number of classes we're working with (pizza, steak, sushi)
vit = ViT(num_classes=len(class_names))

from going_modular.going_modular import engine

# Setup the optimizer to optimize our ViT model parameters using hyperparameters from the ViT paper 
optimizer = torch.optim.Adam(params=vit.parameters(), 
                             lr=3e-3, # Base LR from Table 3 for ViT-* ImageNet-1k
                             betas=(0.9, 0.999), # default values but also mentioned in ViT paper section 4.1 (Training & Fine-tuning)
                             weight_decay=0.3) # from the ViT paper section 4.1 (Training & Fine-tuning) and Table 3 for ViT-* ImageNet-1k

# Setup the loss function for multi-class classification
loss_fn = torch.nn.CrossEntropyLoss()

# Set the seeds
set_seeds()

# Train the model and save the training results to a dictionary
results = engine.train(model=vit,
                       train_dataloader=train_dataloader,
                       test_dataloader=test_dataloader,
                       optimizer=optimizer,
                       loss_fn=loss_fn,
                       epochs=10,
                       device=device)

# %%
#evaluation &visualization 
from helper_functions import plot_loss_curves

# Plot our ViT model's loss curves
plot_loss_curves(results)

# %%
import requests

# Import function to make predictions on images and plot them 
from going_modular.going_modular.predictions import pred_and_plot_image

# Setup custom image path
custom_image_path = "test_img.jpg"

# Predict on custom image
pred_and_plot_image(model=vit,
                    image_path=custom_image_path,
                    class_names=class_names)
